# %%
import pandas as pd
import os
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import numpy as np

# %%
path = os.getcwd()
print(path)
input = pd.read_csv(path + "/Results/analysis_single_input_1-new.csv")
output = pd.read_csv(path + "/Results/analysis_single_output_1-new.csv")
# Out:
# c:\Users\aarc8\Documents\github\MDOAirB_base\framework

# %%
input.head()
# Out:
#    WingArea          x1    x2    x3    x4    x5     x6   x7      x8    x9  \
# 0     142.5  135.692308  30.0  25.0 -2.25  38.5  250.0  6.0  3000.0  50.0
#
#    FanDiameter   x11     x12   x13      x14   x15
# 0         25.0  27.0  1350.0  15.0  38000.0  78.0

# %%
output.head()
# Out:
#             MTOW          DOC   fuel_mass  total_mission_flight_time  mach  \
# 0  132285.975304  14013.10248  7461.43568                 212.137855  0.82
#
#    passenger_capacity       SAR  landing_field_length_computed  \
# 0               243.0  9.326795                    2277.134747
#
#    takeoff_field_length_computed  app_speed  ...  \
# 0                    2115.733673  78.934045  ...
#
#                                             distance  \
# 0  [0.00000000e+00 3.16227766e-05 6.32455532e-05 ...
#
#                                             altitude  \
# 0  [ 7500.          7500.00000568  7500.00001137 ...
#
#                                                 mass  \
# 0  [107957.1255004  107957.12550017 107957.125499...
#
#                                                 time  \
# 0  [0.00000000e+00 1.01919568e-09 2.03839136e-09 ...
#
#                                                  sfc  \
# 0  [  0.50357543   0.50357543   0.50357543   0.50...
#
#                                               thrust  \
# 0  [1.33391836e+05 1.33391836e+05 1.33391836e+05 ...
#
#                                               mach.1  \
# 0  [0.48322451 0.48322451 0.48322451 0.483225   0...
#
#                                                   CL  \
# 0  [0.59250949 0.59250949 0.59250949 0.59250955 0...
#
#                                                   CD  \
# 0  [0.03140004 0.03140004 0.03140004 0.03140004 0...
#
#                                                  LoD
# 0  [18.86970476 18.86970476 18.86970476 18.869705...
#
# [1 rows x 22 columns]

# %%
distance = output['distance'].apply(lambda x:
                           np.fromstring(
                               x.replace('\n', '')
                                .replace('[', '')
                                .replace(']', '')
                                .replace('  ', ' '), sep=' '))[0]
mass = output['mass'].apply(lambda x:
                           np.fromstring(
                               x.replace('\n', '')
                                .replace('[', '')
                                .replace(']', '')
                                .replace('  ', ' '), sep=' '))[0]
altitude = output['altitude'].apply(lambda x:
                           np.fromstring(
                               x.replace('\n', '')
                                .replace('[', '')
                                .replace(']', '')
                                .replace('  ', ' '), sep=' '))[0]
time = output['time'].apply(lambda x:
                           np.fromstring(
                               x.replace('\n', '')
                                .replace('[', '')
                                .replace(']', '')
                                .replace('  ', ' '), sep=' '))[0]
LoD = output['LoD'].apply(lambda x:
                           np.fromstring(
                               x.replace('\n', '')
                                .replace('[', '')
                                .replace(']', '')
                                .replace('  ', ' '), sep=' '))[0]
sfc = output['sfc'].apply(lambda x:
                           np.fromstring(
                               x.replace('\n', '')
                                .replace('[', '')
                                .replace(']', '')
                                .replace('  ', ' '), sep=' '))[0]
CL = output['CL'].apply(lambda x:
                           np.fromstring(
                               x.replace('\n', '')
                                .replace('[', '')
                                .replace(']', '')
                                .replace('  ', ' '), sep=' '))[0]
CD = output['CD'].apply(lambda x:
                           np.fromstring(
                               x.replace('\n', '')
                                .replace('[', '')
                                .replace(']', '')
                               .replace('  ', ' '), sep=' '))[0]
mach = output['mach.1'].apply(lambda x:
                        np.fromstring(
                            x.replace('\n', '')
                            .replace('[', '')
                            .replace(']', '')
                            .replace('  ', ' '), sep=' '))[0]

# %%
plt.plot(distance, time)
plt.grid()
plt.show()

# %%
plt.plot(distance,altitude)
plt.grid()
plt.show()

# %%
print(distance[-1]*0.000539957)
print(time[-1])
print(mass[0]-mass[-1])
print(altitude[0])
print(altitude[-1])
# Out:
# 460.42430906307
# 104.237855
# 7093.400025359995
# 7500.0
# 13080.69409683

# %%
plt.plot(time, LoD)
plt.grid()
plt.show()

# %%
plt.plot(distance, sfc)
plt.grid()
plt.show()

# %%
plt.plot(distance, CL)
plt.grid()
plt.show()

# %%
plt.plot(distance, CD)
plt.grid()
plt.show()

# %%
plt.plot(distance, mach)
plt.grid()
plt.show()
