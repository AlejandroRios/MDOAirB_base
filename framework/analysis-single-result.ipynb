# %%
import pandas as pd
import os
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import numpy as np

# %%
path = os.getcwd()
print(path)
input = pd.read_csv(path + "/Results/analysis_single_input_1-new.csv")
output = pd.read_csv(path + "/Results/analysis_single_output_1-new.csv")
# Out:
# /Users/to127534/MDO_update/MDOAirB_base-main/framework

# %%
input.head()
# Out:
#    WingArea          x1    x2    x3    x4    x5     x6   x7      x8    x9  \
# 0     142.5  135.692308  30.0  25.0 -2.25  38.5  250.0  6.0  3000.0  50.0
#
#    FanDiameter   x11     x12   x13      x14   x15
# 0         25.0  27.0  1350.0  15.0  38000.0  78.0

# %%
output.head()
# Out:
#             MTOW           DOC    fuel_mass  total_mission_flight_time  mach  \
# 0  123387.686303  13708.894716  6777.766355                  216.77769  0.82
#
#    passenger_capacity       SAR  landing_field_length_computed  \
# 0               242.0  8.472208                    2161.803337
#
#    takeoff_field_length_computed  app_speed  ...  \
# 0                    1570.490009  76.650019  ...
#
#                                             distance  \
# 0  [0.00000000e+00 3.16227766e-05 6.32455532e-05 ...
#
#                                             altitude  \
# 0  [ 1500.          1500.00000747  1500.00001493 ...
#
#                                                 mass  \
# 0  [101535.97770175 101535.97770147 101535.977701...
#
#                                                 time  \
# 0  [0.00000000e+00 1.12222335e-09 2.24444670e-09 ...
#
#                                                  sfc  \
# 0  [ 0.004891    0.004891    0.004891    0.004891...
#
#                                               thrust  \
# 0  [ 1.53076666e+05  1.53076666e+05  1.53076666e+...
#
#                                               mach.1  \
# 0  [0.43446873 0.43446873 0.43446873 0.4344693  0...
#
#                                                   CL  \
# 0  [0.55113546 0.55113546 0.55113546 0.55113551 0...
#
#                                                   CD  \
# 0  [0.02997914 0.02997914 0.02997914 0.02997914 0...
#
#                                                  LoD
# 0  [18.38396323 18.38396323 18.38396323 18.383963...
#
# [1 rows x 22 columns]

# %%
distance = output['distance'].apply(lambda x:
                           np.fromstring(
                               x.replace('\n', '')
                                .replace('[', '')
                                .replace(']', '')
                                .replace('  ', ' '), sep=' '))[0]
mass = output['mass'].apply(lambda x:
                           np.fromstring(
                               x.replace('\n', '')
                                .replace('[', '')
                                .replace(']', '')
                                .replace('  ', ' '), sep=' '))[0]
altitude = output['altitude'].apply(lambda x:
                           np.fromstring(
                               x.replace('\n', '')
                                .replace('[', '')
                                .replace(']', '')
                                .replace('  ', ' '), sep=' '))[0]
time = output['time'].apply(lambda x:
                           np.fromstring(
                               x.replace('\n', '')
                                .replace('[', '')
                                .replace(']', '')
                                .replace('  ', ' '), sep=' '))[0]
LoD = output['LoD'].apply(lambda x:
                           np.fromstring(
                               x.replace('\n', '')
                                .replace('[', '')
                                .replace(']', '')
                                .replace('  ', ' '), sep=' '))[0]
sfc = output['sfc'].apply(lambda x:
                           np.fromstring(
                               x.replace('\n', '')
                                .replace('[', '')
                                .replace(']', '')
                                .replace('  ', ' '), sep=' '))[0]
CL = output['CL'].apply(lambda x:
                           np.fromstring(
                               x.replace('\n', '')
                                .replace('[', '')
                                .replace(']', '')
                                .replace('  ', ' '), sep=' '))[0]
CD = output['CD'].apply(lambda x:
                           np.fromstring(
                               x.replace('\n', '')
                                .replace('[', '')
                                .replace(']', '')
                               .replace('  ', ' '), sep=' '))[0]
mach = output['mach.1'].apply(lambda x:
                        np.fromstring(
                            x.replace('\n', '')
                            .replace('[', '')
                            .replace(']', '')
                            .replace('  ', ' '), sep=' '))[0]

# %%
plt.plot(distance, time)
plt.grid()
plt.show()

# %%
plt.plot(distance,altitude)
plt.grid()
plt.show()

# %%
print(distance[-1]*0.000539957)
print(time[-1])
print(mass[0]-mass[-1])
print(altitude[0])
print(altitude[-1])
# Out:
# 853.0843817969
# 108.87769
# 6431.62097607
# 1500.0
# 748.61030162

# %%
plt.plot(time, LoD)
plt.grid()
plt.show()

# %%
plt.plot(distance, sfc)
plt.grid()
plt.show()

# %%
plt.plot(distance, CL)
plt.grid()
plt.show()

# %%
plt.plot(distance, CD)
plt.grid()
plt.show()

# %%
plt.plot(distance, mach)
plt.grid()
plt.show()
